# %% [markdown]
# ## Importing Libraries

# %%
#Importing necessary packages
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading Train Datasets

# %%
traindf1 = pd.read_csv('Train_Claim.csv')
traindf2 = pd.read_csv('Train_Demographics.csv')
traindf3 = pd.read_csv('Train_Policy.csv')
traindf4 = pd.read_csv('Train_Vehicle.csv')
traindf5 = pd.read_csv('Traindata_with_Target.csv')

# %%
traindf1.shape
# Out:
# (28836, 19)

# %%
traindf1.head()
# Out:
#   CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0  Cust10000     2015-02-03   Multi-vehicle Collision   Side Collision
# 1  Cust10001     2015-02-02   Multi-vehicle Collision   Side Collision
# 2  Cust10002     2015-01-15  Single Vehicle Collision   Side Collision
# 3  Cust10003     2015-01-19  Single Vehicle Collision   Side Collision
# 4  Cust10004     2015-01-09  Single Vehicle Collision   Rear Collision
#
#   SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0         Total Loss               Police        State7        City1
# 1         Total Loss               Police        State7        City5
# 2       Minor Damage                Other        State8        City6
# 3       Minor Damage                Other        State9        City6
# 4       Minor Damage                 Fire        State8        City6
#
#   IncidentAddress  IncidentTime  NumberOfVehicles PropertyDamage  \
# ...

# %%
traindf1.isnull().sum()
# Out:
# CustomerID               0
# DateOfIncident           0
# TypeOfIncident           0
# TypeOfCollission         0
# SeverityOfIncident       0
# AuthoritiesContacted     0
# IncidentState            0
# IncidentCity             0
# IncidentAddress          0
# IncidentTime             0
# NumberOfVehicles         0
# PropertyDamage           0
# BodilyInjuries           0
# Witnesses                0
# PoliceReport             0
# AmountOfTotalClaim       0
# AmountOfInjuryClaim      0
# AmountOfPropertyClaim    0
# AmountOfVehicleDamage    0
# dtype: int64

# %%
traindf2.shape
# Out:
# (28836, 10)

# %%
traindf2.head()
# Out:
#   CustomerID  InsuredAge  InsuredZipCode InsuredGender InsuredEducationLevel  \
# 0  Cust10000          35          454776          MALE                    JD
# 1  Cust10001          36          454776          MALE                    JD
# 2  Cust10002          33          603260          MALE                    JD
# 3  Cust10003          36          474848          MALE                    JD
# 4  Cust10004          29          457942        FEMALE           High School
#
#   InsuredOccupation InsuredHobbies  CapitalGains  CapitalLoss Country
# 0      armed-forces         movies         56700       -48500   India
# 1      tech-support      cross-fit         70600       -48500   India
# 2      armed-forces           polo         66400       -63700   India
# 3      armed-forces           polo         47900       -73400   India
# 4   exec-managerial        dancing             0       -41500   India

# %%
traindf2.isnull().sum()
# Out:
# CustomerID                0
# InsuredAge                0
# InsuredZipCode            0
# InsuredGender            30
# InsuredEducationLevel     0
# InsuredOccupation         0
# InsuredHobbies            0
# CapitalGains              0
# CapitalLoss               0
# Country                   2
# dtype: int64

# %%
traindf3.shape
# Out:
# (28836, 10)

# %%
traindf3.head()
# Out:
#    InsurancePolicyNumber  CustomerLoyaltyPeriod DateOfPolicyCoverage  \
# 0                 110122                    328           2014-10-17
# 1                 110125                    256           1990-05-25
# 2                 110126                    228           2014-06-06
# 3                 110127                    256           2006-10-12
# 4                 110128                    137           2000-06-04
#
#   InsurancePolicyState Policy_CombinedSingleLimit  Policy_Deductible  \
# 0               State3                    250/500               1000
# 1               State1                    250/500               2000
# 2               State1                   500/1000               1000
# 3               State3                    250/500               1000
# 4               State2                    250/500               1000
#
#    PolicyAnnualPremium  UmbrellaLimit InsuredRelationship CustomerID
# ...

# %%
traindf3.isnull().sum()
# Out:
# InsurancePolicyNumber         0
# CustomerLoyaltyPeriod         0
# DateOfPolicyCoverage          0
# InsurancePolicyState          0
# Policy_CombinedSingleLimit    0
# Policy_Deductible             0
# PolicyAnnualPremium           0
# UmbrellaLimit                 0
# InsuredRelationship           0
# CustomerID                    0
# dtype: int64

# %%
traindf4.shape
# Out:
# (115344, 3)

# %%
traindf4.head()
# Out:
#   CustomerID VehicleAttribute VehicleAttributeDetails
# 0  Cust20179        VehicleID             Vehicle8898
# 1  Cust21384     VehicleModel                  Malibu
# 2  Cust33335      VehicleMake                  Toyota
# 3  Cust27118     VehicleModel                    Neon
# 4  Cust13038        VehicleID            Vehicle30212

# %%
traindf4.isnull().sum()
# Out:
# CustomerID                 0
# VehicleAttribute           0
# VehicleAttributeDetails    0
# dtype: int64

# %%
traindf5.shape
# Out:
# (28836, 2)

# %%
traindf5.head()
# Out:
#   CustomerID ReportedFraud
# 0  Cust20065             N
# 1  Cust37589             N
# 2  Cust24312             N
# 3   Cust5493             Y
# 4   Cust7704             Y

# %%
traindf5.isnull().sum()
# Out:
# CustomerID       0
# ReportedFraud    0
# dtype: int64

# %% [markdown]
# ## Merging Train Datasets

# %%
merged_train_df = pd.merge(traindf1, traindf2, on='CustomerID', how='outer')
merged_train_df = pd.merge(traindf1, traindf2, on='CustomerID', how='outer')
merged_train_df = pd.merge(merged_train_df, traindf3, on='CustomerID', how='outer')
merged_train_df = pd.merge(merged_train_df, traindf4, on='CustomerID', how='outer')
merged_train_df = pd.merge(merged_train_df, traindf5, on='CustomerID', how='outer')

# %%
merged_train_df.shape
# Out:
# (115344, 40)

# %%
merged_train_df.head()
# Out:
#   CustomerID DateOfIncident           TypeOfIncident TypeOfCollission  \
# 0  Cust10000     2015-02-03  Multi-vehicle Collision   Side Collision
# 1  Cust10000     2015-02-03  Multi-vehicle Collision   Side Collision
# 2  Cust10000     2015-02-03  Multi-vehicle Collision   Side Collision
# 3  Cust10000     2015-02-03  Multi-vehicle Collision   Side Collision
# 4  Cust10001     2015-02-02  Multi-vehicle Collision   Side Collision
#
#   SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0         Total Loss               Police        State7        City1
# 1         Total Loss               Police        State7        City1
# 2         Total Loss               Police        State7        City1
# 3         Total Loss               Police        State7        City1
# 4         Total Loss               Police        State7        City5
#
#   IncidentAddress  IncidentTime  ...  DateOfPolicyCoverage  \
# 0   Location 1311            17  ...            1998-10-25
# ...

# %% [markdown]
# Here, the Target Column is ReportedFraud

# %%
merged_train_df.dtypes
# Out:
# CustomerID                     object
# DateOfIncident                 object
# TypeOfIncident                 object
# TypeOfCollission               object
# SeverityOfIncident             object
# AuthoritiesContacted           object
# IncidentState                  object
# IncidentCity                   object
# IncidentAddress                object
# IncidentTime                    int64
# NumberOfVehicles                int64
# PropertyDamage                 object
# BodilyInjuries                  int64
# Witnesses                      object
# PoliceReport                   object
# AmountOfTotalClaim             object
# AmountOfInjuryClaim             int64
# AmountOfPropertyClaim           int64
# AmountOfVehicleDamage           int64
# InsuredAge                      int64
# InsuredZipCode                  int64
# InsuredGender                  object
# InsuredEducationLevel          object
# InsuredOccupation              object
# InsuredHobbies                 object
# ...

# %%
merged_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115344 entries, 0 to 115343
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   CustomerID                  115344 non-null  object
#  1   DateOfIncident              115344 non-null  object
#  2   TypeOfIncident              115344 non-null  object
#  3   TypeOfCollission            115344 non-null  object
#  4   SeverityOfIncident          115344 non-null  object
#  5   AuthoritiesContacted        115344 non-null  object
#  6   IncidentState               115344 non-null  object
#  7   IncidentCity                115344 non-null  object
#  8   IncidentAddress             115344 non-null  object
#  9   IncidentTime                115344 non-null  int64
#  10  NumberOfVehicles            115344 non-null  int64
#  11  PropertyDamage              115344 non-null  object
#  12  BodilyInjuries              115344 non-null  int64
# ...

# %%
merged_train_df.describe()
# Out:
#         IncidentTime  NumberOfVehicles  BodilyInjuries  AmountOfInjuryClaim  \
# count  115344.000000     115344.000000   115344.000000        115344.000000
# mean       11.746047          1.823207        0.985782          7337.118428
# std         6.169989          0.980086        0.784754          4427.581013
# min        -5.000000          1.000000        0.000000             0.000000
# 25%         6.000000          1.000000        0.000000          4743.750000
# 50%        12.000000          1.000000        1.000000          7147.000000
# 75%        17.000000          3.000000        2.000000         10571.250000
# max        23.000000          4.000000        2.000000         21450.000000
#
#        AmountOfPropertyClaim  AmountOfVehicleDamage     InsuredAge  \
# count          115344.000000          115344.000000  115344.000000
# mean             7283.870197           37687.129387      38.815370
# std              4375.785831           17976.814444       7.996273
# ...

# %%
merged_train_df.isnull().sum()
# Out:
# CustomerID                      0
# DateOfIncident                  0
# TypeOfIncident                  0
# TypeOfCollission                0
# SeverityOfIncident              0
# AuthoritiesContacted            0
# IncidentState                   0
# IncidentCity                    0
# IncidentAddress                 0
# IncidentTime                    0
# NumberOfVehicles                0
# PropertyDamage                  0
# BodilyInjuries                  0
# Witnesses                       0
# PoliceReport                    0
# AmountOfTotalClaim              0
# AmountOfInjuryClaim             0
# AmountOfPropertyClaim           0
# AmountOfVehicleDamage           0
# InsuredAge                      0
# InsuredZipCode                  0
# InsuredGender                 120
# InsuredEducationLevel           0
# InsuredOccupation               0
# InsuredHobbies                  0
# CapitalGains                    0
# CapitalLoss                     0
# ...

# %%
#missing value function
def missing_data(data):
    total = data.isnull().sum()
    percent = (data.isnull().sum()/data.isnull().count()*100)
    tt = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    types = []
    for col in data.columns:
        dtype = str(data[col].dtype)
        types.append(dtype)
    tt['Types'] = types
    return tt    

missing_data(merged_train_df)['Percent'].sort_values(ascending=False)
# Out:
# InsuredGender                 0.104037
# Country                       0.006936
# DateOfIncident                0.000000
# InsuredEducationLevel         0.000000
# InsuredOccupation             0.000000
# InsuredHobbies                0.000000
# CapitalGains                  0.000000
# CapitalLoss                   0.000000
# InsurancePolicyNumber         0.000000
# CustomerLoyaltyPeriod         0.000000
# CustomerID                    0.000000
# InsurancePolicyState          0.000000
# Policy_CombinedSingleLimit    0.000000
# Policy_Deductible             0.000000
# PolicyAnnualPremium           0.000000
# UmbrellaLimit                 0.000000
# InsuredRelationship           0.000000
# VehicleAttribute              0.000000
# VehicleAttributeDetails       0.000000
# DateOfPolicyCoverage          0.000000
# InsuredZipCode                0.000000
# InsuredAge                    0.000000
# IncidentTime                  0.000000
# TypeOfIncident                0.000000
# ...

# %% [markdown]
# ## Loading Test Datasets

# %%
testdf1 = pd.read_csv('Test.csv')
testdf2 = pd.read_csv('Test_Claim.csv')
testdf3 = pd.read_csv('Test_Demographics.csv')
testdf4 = pd.read_csv('Test_Policy.csv')
testdf5 = pd.read_csv('Test_Vehicle.csv')

# %%
testdf1.shape
# Out:
# (8912, 1)

# %%
testdf1.head()
# Out:
#   CustomerID
# 0  Cust10008
# 1  Cust10010
# 2  Cust10015
# 3  Cust10020
# 4   Cust1003

# %%
testdf2.shape
# Out:
# (8912, 19)

# %%
testdf2.head()
# Out:
#   CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0  Cust10008     2015-02-05   Multi-vehicle Collision  Front Collision
# 1  Cust10010     2015-01-13  Single Vehicle Collision   Rear Collision
# 2  Cust10015     2015-01-05   Multi-vehicle Collision   Rear Collision
# 3  Cust10020     2015-01-03             Vehicle Theft                ?
# 4   Cust1003     2015-02-22   Multi-vehicle Collision   Rear Collision
#
#   SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0       Minor Damage            Ambulance        State5        City2
# 1       Minor Damage                 Fire        State9        City5
# 2       Minor Damage               Police        State5        City2
# 3     Trivial Damage                 None        State7        City5
# 4       Minor Damage               Police        State5        City2
#
#   IncidentAddress  IncidentTime  NumberOfVehicles PropertyDamage  \
# ...

# %%
testdf3.shape
# Out:
# (8912, 10)

# %%
testdf3.head()
# Out:
#   CustomerID  InsuredAge  InsuredZipCode InsuredGender InsuredEducationLevel  \
# 0  Cust10008          27          471704        FEMALE           High School
# 1  Cust10010          40          455810        FEMALE                    MD
# 2  Cust10015          39          461919          MALE                    JD
# 3  Cust10020          38          600904        FEMALE               Masters
# 4   Cust1003          29          430632        FEMALE                   PhD
#
#   InsuredOccupation InsuredHobbies  CapitalGains  CapitalLoss Country
# 0      adm-clerical   base-jumping         56400       -57000   India
# 1    prof-specialty           golf         56700       -65600   India
# 2     other-service         movies         30400            0   India
# 3   exec-managerial    video-games         68500            0   India
# 4             sales    board-games         35100            0   India

# %%
testdf4.shape
# Out:
# (8912, 10)

# %%
testdf4.head()
# Out:
#    InsurancePolicyNumber  CustomerLoyaltyPeriod DateOfPolicyCoverage  \
# 0                 110124                    134           2000-09-06
# 1                 110129                    165           1990-02-03
# 2                 110137                    473           1992-10-19
# 3                 110140                    160           2014-12-28
# 4                 110141                    196           1992-08-02
#
#   InsurancePolicyState Policy_CombinedSingleLimit  Policy_Deductible  \
# 0               State3                    100/300               2000
# 1               State1                    100/300               1000
# 2               State2                    100/300               2000
# 3               State3                   500/1000                500
# 4               State2                   500/1000               2000
#
#    PolicyAnnualPremium  UmbrellaLimit InsuredRelationship CustomerID
# ...

# %%
testdf5.shape
# Out:
# (35648, 3)

# %%
testdf5.head()
# Out:
#   CustomerID VehicleAttribute VehicleAttributeDetails
# 0  Cust28465     VehicleModel                     92x
# 1  Cust20319     VehicleModel                   Jetta
# 2   Cust3683        VehicleID            Vehicle22709
# 3  Cust29385        VehicleID            Vehicle20347
# 4  Cust34403     VehicleModel                   Camry

# %% [markdown]
# ## Merging Test Datasets

# %%
# Merge the first two datasets on a common column
merged_test_df = pd.merge(testdf1, testdf2, on='CustomerID',how='outer')

# Merge the third dataset with the merged dataset on a common column
merged_test_df = pd.merge(merged_test_df, testdf3, on='CustomerID',how='outer')

# Merge the fourth dataset with the merged dataset on a common column
merged_test_df = pd.merge(merged_test_df, testdf4, on='CustomerID',how='outer')

# Merge the fifth dataset with the merged dataset on a common column
merged_test_df = pd.merge(merged_test_df, testdf5, on='CustomerID',how='outer')

# %%
merged_test_df.shape
# Out:
# (35648, 39)

# %%
merged_test_df.head()
# Out:
#   CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0  Cust10008     2015-02-05   Multi-vehicle Collision  Front Collision
# 1  Cust10008     2015-02-05   Multi-vehicle Collision  Front Collision
# 2  Cust10008     2015-02-05   Multi-vehicle Collision  Front Collision
# 3  Cust10008     2015-02-05   Multi-vehicle Collision  Front Collision
# 4  Cust10010     2015-01-13  Single Vehicle Collision   Rear Collision
#
#   SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0       Minor Damage            Ambulance        State5        City2
# 1       Minor Damage            Ambulance        State5        City2
# 2       Minor Damage            Ambulance        State5        City2
# 3       Minor Damage            Ambulance        State5        City2
# 4       Minor Damage                 Fire        State9        City5
#
#   IncidentAddress  IncidentTime  ...  CustomerLoyaltyPeriod  \
# ...
